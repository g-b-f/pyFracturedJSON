# %% [markdown]
# Iterating and testing with FracturedJSON

# %%
long_list = [f"thing_{i}" for i in range(20)]
data = dict(abcd = "abcd", long_list = long_list)

# %%
from fractured_json import FracturedJson
import json

json.dumps(data, cls=FracturedJson)
# Out:
# called, oneshot= True
# '{"abcd": "abcd", "long_list": ["thing_0", "thing_1", "thing_2", "thing_3", "thing_4", "thing_5", "thing_6", "thing_7", "thing_8", "thing_9", "thing_10", "thing_11", "thing_12", "thing_13", "thing_14", "thing_15", "thing_16", "thing_17", "thing_18", "thing_19"]}'

# %%
from reformat_json import reformat_json

# reformat_json(m: &Bound<'_, PyModule>) -> PyResult<()> {
#     m.add_function(wrap_pyfunction!(reformat, m)?);
